# %%
#import libraries
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Generate and display dataframe
np.random.seed(30)
df = pd.DataFrame(np.random.randn(10, 5), columns=list('ABCDE'))
df
# Out:
#           A         B         C         D         E
# 0 -1.264053  1.527905 -0.970711  0.470560 -0.100697
# 1  0.303793 -1.725962  1.585095  0.134297 -1.106855
# 2  1.578226  0.107498 -0.764048 -0.775189  1.383847
# 3  0.760385 -0.285646  0.538367 -2.083897  0.937782
# 4 -0.005778 -0.467479 -0.423015  1.064482 -2.903368
# 5  1.616890  1.425510 -0.664755  0.985018 -1.700465
# 6 -1.100144 -1.315644  0.810501 -1.044778 -0.689229
# 7 -0.852757  1.113472 -1.921170 -0.701402  0.849088
# 8  1.050700 -0.536874 -0.029193  1.394056 -0.397867
# 9  1.019127  1.898881 -0.354850 -0.387016 -1.927305

# %%
# Bar plot over pandas dataframe
df.style.bar(color = ['#d65f5f', '#5fba7d'], align = 'zero')
# Out:
# <style  type="text/css" >
#     #T_f0eb7aee_4c06_11ea_81d9_74e6e243b139row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.9%, #d65f5f 10.9%, #d65f5f 50%, transparent 50%);
#         }    #T_f0eb7aee_4c06_11ea_81d9_74e6e243b139row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #5fba7d 50%, #5fba7d 90.2%, transparent 90.2%);
#         }    #T_f0eb7aee_4c06_11ea_81d9_74e6e243b139row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 24.7%, #d65f5f 24.7%, #d65f5f 50%, transparent 50%);
#         }    #T_f0eb7aee_4c06_11ea_81d9_74e6e243b139row0_col3 {
#             width:  10em;
#              height:  80%;
# ...
