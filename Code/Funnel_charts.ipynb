# %% [markdown]
# # Plot Funnel Chart using plotly

# %%
from plotly import graph_objects as go

# %%
y = ['Social Media Reach', 'Landing page', 'Cart', 'Buy' ]
x = [3000, 1000, 300, 50]

# %%
fig = go.Figure(go.Funnel( y=y, x=x))

fig.show()
# Out:
# <div>
#
#
#             <div id="2dd5facc-964f-4903-879c-4f41b94cd802" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2dd5facc-964f-4903-879c-4f41b94cd802")) {
#                     Plotly.newPlot(
#                         '2dd5facc-964f-4903-879c-4f41b94cd802',
#                         [{"type": "funnel", "x": [3000, 1000, 300, 50], "y": ["Social Media Reach", "Landing page", "Cart", "Buy"]}],
# ...
